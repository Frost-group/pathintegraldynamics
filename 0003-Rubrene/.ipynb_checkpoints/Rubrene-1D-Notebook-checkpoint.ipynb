# %%
using QuantumDynamics
using Plots
using LinearAlgebra

# %% [markdown]
# Hoping to get rid of the units issue by integrating Unitful into QuantumDynamics package.

# %%
const thz2au = 0.0001519828500716
const invcm2au = 4.55633e-6
const au2fs = 0.02418884254
const mev2invcm = 8.066
# Out:
# 8.066

# %%
struct fitsd <: SpectralDensities.AnalyticalSpectralDensity
    ωs :: Vector{Float64}
    jws :: Vector{Float64}
    ωmax :: Real
    Δs :: Real
    classical :: Bool
end

# %% [markdown]
# The evaluate function doesn't matter as much. Propagation relies primarily on tabulating the spectral density. Would like to do a Gaussian blur at each point when tabulating / discretizing.

# %%
function evaluate(sd::fitsd, ω::Real)
    ωs = sd.ωs
    jws = sd.jws
    for i in 1:(size(ωs)[1]-1)
        if ω > ωs[i] && ω < ωs[i+1]
            return jws[i] + ((jws[i+1]-jws[i])/(ωs[i+1] - ωs[i]))*(ω - ωs[i])
        end
    end
    return 0.0
end
# Out:
# evaluate (generic function with 1 method)

# %%
function tabulate(sd::fitsd, full_real::Bool=true, npoints::Int=5)
    sd.ωs, sd.jws
end
# Out:
# tabulate (generic function with 3 methods)

# %%
function discretize(sd::fitsd, num_osc::Int)
    sd.ωs, sd.jws
end
# Out:
# discretize (generic function with 1 method)

# %%
(sd::fitsd)(ω::Real) = evaluate(sd, ω)

# %% [markdown]
# Ordejon paper mentions that Hamiltonian electronic terms are $\epsilon_0$ , $\epsilon_{AA+b}$ and $\epsilon_{AA+2b}$ for nearest 2 neighbours and additionally mentions that the coupling terms for nearest 2 neighbours on either side. Further mentions the couplings $\epsilon$AB, AC, AD for neighbours on the same unit cell. However, the value for $\epsilon_0$ (site energies) isn't mentioned in the paper? Perhaps worth doing some TD-DFT ourselves? Or alternatively some TrESP-ish method for 1-D... have to think about this for a bit

# %%
ϵ0 = 12000 # Completely arbitrary value 
ϵb = 134.0
ϵ2b = -10.7
# Out:
# -10.7

# %%
N = 10
# Out:
# 10

# %%
H0 = Matrix{ComplexF64}(zeros(N, N))
# Out:
# 10×10 Matrix{ComplexF64}:
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  …  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  …  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im

# %%
for i in 1:N
    H0[i,i] = ϵ0
    if i <= N-2
        H0[i, i+2] = ϵ2b
    end
    if i <= N-1
        H0[i, i+1] = ϵb
    end
    if i >= 2
        H0[i, i-1] = ϵb
    end
    if i>=3
        H0[i, i-2] = ϵ2b
    end
end

# %%
H0 = H0 * invcm2au
# Out:
# 10×10 Matrix{ComplexF64}:
#     0.054676+0.0im  0.000610548+0.0im  …          0.0+0.0im
#  0.000610548+0.0im     0.054676+0.0im             0.0+0.0im
#  -4.87527e-5+0.0im  0.000610548+0.0im             0.0+0.0im
#          0.0+0.0im  -4.87527e-5+0.0im             0.0+0.0im
#          0.0+0.0im          0.0+0.0im             0.0+0.0im
#          0.0+0.0im          0.0+0.0im  …          0.0+0.0im
#          0.0+0.0im          0.0+0.0im             0.0+0.0im
#          0.0+0.0im          0.0+0.0im     -4.87527e-5+0.0im
#          0.0+0.0im          0.0+0.0im     0.000610548+0.0im
#          0.0+0.0im          0.0+0.0im        0.054676+0.0im

# %%
ωp = [57.8, 59.6, 89.0, 107.3, 139.1, 639.1, 1011.2, 1344.7, 1593.3] .* invcm2au
ωpg0p = [-1.7, 1.4, 1.6, -0.14, -2.3, -7.5, -3.6, 19.8, -42.0] * invcm2au
g0p = ωpg0p ./ ωp
jws = ((g0p.^(2))./ωp)
#Jw = SpectralDensities.ExponentialCutoff(; ξ=30.0, ωc=57.8*invcm2au, n=0.0, Δs=1.0)
wm = maximum(ωp)
Jw = fitsd(ωp, jws, wm, 1.0, false)
# Out:
# fitsd([0.000263355874, 0.00027155726800000003, 0.00040551337, 0.0004888942090000001, 0.000633785503, 0.002911950503, 0.004607360896, 0.006126896951000001, 0.007259600589], [3.284726062780688, 2.0318990209622005, 0.7969934905542059, 0.0034821039706774974, 0.4313791108898418, 0.04729343983355628, 0.002750924350825124, 0.035386612864194956, 0.095717366517124], 0.007259600589, 1.0, false)

# %%
ω = 0:0.0001:0.07
plot(ω, Jw.(ω))

# %%
nsteps = 1000
ρ0 = Matrix{ComplexF64}(zeros(N, N))
ρ0[5, 5] = 1

T = 50.0:50.0:500.0

β = 1 / (T[6] * 3.16683e-6) # T = 300K
# Out:
# 1052.5772881188234

# %% [markdown]
# Simulation is very sensitive to time-stepping. NaNs get produced if you're not careful

# %%
dt = 0.001 / au2fs
# Out:
# 0.04134137457575099

# %%
fbU = Propagators.calculate_bare_propagators(; Hamiltonian=H0, dt=dt, ntimes=nsteps)    
t, ρ = TTM.propagate(; fbU=fbU, Jw=[Jw], β=β, ρ0=ρ0, dt=dt, ntimes=nsteps, rmax=1, extraargs=QuAPI.QuAPIArgs(), path_integral_routine=QuAPI.build_augmented_propagator)
# Out:
# (0.0:0.04134137457575099:41.34137457575099, [0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; 4.1254895338660144e-24 + 0.0im -1.0333001053719202e-22 + 2.711480386288953e-26im … 4.125489533208924e-24 + 1.5179259571213972e-37im -2.1891489674973704e-32 - 1.0413107354437287e-28im; … ; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; -1.0332995961418598e-22 - 2.7114790500195444e-26im 2.588078754092306e-21 + 0.0im … -1.0333001052073406e-22 - 2.71148038623727e-26im -1.3609191631418421e-31 + 2.60814272629835e-27im; … ; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; -6.470193729977502e-22 + 4.093750702321386e-18im -1.070048781372018e-20 - 1.0253511146860438e-16im … -6.470196919090016e-22 + 4.093752719149009e-18im 1.0333001119089706e-22 - 5.3917214180144204e-27im; … ; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; 1.6102396724834214e-20 - 5.126755491311232e-17im -6.635603484265055e-20 + 1.2840845631807983e-15im … 1.6102396724155793e-20 - 5.1267554904946657e-17im -1.2940393715167547e-21 - 1.3439294997635578e-25im; … ; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; -2.0311300097131845e-12 - 6.42042281414236e-16im 5.0873163291786234e-11 + 2.7314440572326634e-15im … -2.031130009389675e-12 - 6.420422813867063e-16im -5.427741412155184e-21 + 5.126755521706227e-17im; … ; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; 1.6102396724834202e-20 - 5.1267554913112335e-17im -6.635603484265016e-20 + 1.2840845631807985e-15im … 1.610239672415578e-20 - 5.126755490494666e-17im -1.2940393715167549e-21 - 1.343929499763554e-25im; … ; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; -6.470196918614327e-22 + 4.093752719801045e-18im -1.070048781372018e-20 - 1.0253511146860438e-16im … -6.470196919090016e-22 + 4.093752719149009e-18im 1.0333001119089706e-22 - 5.3917214180144204e-27im; … ; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; -1.0333001053713954e-22 - 2.711480386288069e-26im 2.588078754090992e-21 + 1.2416159080560412e-37im … -1.0333001052068159e-22 - 2.7114803862363864e-26im -1.3609191631423957e-31 + 2.608142726297026e-27im; … ; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; 4.125489533208924e-24 - 1.5179259571213972e-37im -1.0333001052073406e-22 + 2.71148038623727e-26im … 4.125489532551834e-24 + 0.0im -2.1891489675318248e-32 - 1.0413107352778735e-28im; … ; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; -2.1891489674973704e-32 + 1.0413107354437287e-28im -1.3609191631418421e-31 - 2.60814272629835e-27im … -2.1891489675318248e-32 + 1.0413107352778735e-28im 2.6283622507653358e-33 + 0.0im; … ; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im; NaN + NaN*im NaN + NaN*im … NaN + NaN*im NaN + NaN*im])

# %% [markdown]
# QCPI doesn't compile. I need to figure out where the pipeline is going wrong

# %%
## QCPI Run

ω, c = discretize(Jw, 9)
hb = Solvents.HarmonicBath(β, ω, c, [1.0, -1.0], 10)

tc, ρc = QCPI.propagate(; Hamiltonian=H0, Jw, solvent=hb, ρ0, classical_dt=dt / 100, dt, ntimes=nsteps, kmax=1, extraargs=QuAPI.QuAPIArgs(), path_integral_routine=QuAPI.propagate, verbose=false)
# Out:
# DimensionMismatch: array could not be broadcast to match destination
#
# Stacktrace:
#   [1] check_broadcast_shape
#     @ ./broadcast.jl:553 [inlined]
#   [2] check_broadcast_axes
#     @ ./broadcast.jl:556 [inlined]
#   [3] check_broadcast_axes
#     @ ./broadcast.jl:560 [inlined]
#   [4] instantiate
#     @ ./broadcast.jl:297 [inlined]
#   [5] materialize!
#     @ ./broadcast.jl:884 [inlined]
#   [6] materialize!
#     @ ./broadcast.jl:881 [inlined]
#   [7] calculate_reference_propagators(; Hamiltonian::Matrix{ComplexF64}, solvent::QuantumDynamics.Solvents.HarmonicBath, ps::QuantumDynamics.Solvents.HarmonicPhaseSpace, classical_dt::Float64, dt::Float64, ref_pos::Nothing, ntimes::Int64)
#     @ QuantumDynamics.Propagators ~/.julia/packages/QuantumDynamics/bk7Hq/src/Propagators.jl:48
#   [8] calculate_reference_propagators
#     @ ~/.julia/packages/QuantumDynamics/bk7Hq/src/Propagators.jl:25 [inlined]
#   [9] propagate(; Hamiltonian::Matrix{ComplexF64}, Jw::fitsd, solvent::QuantumDynamics.Solvents.HarmonicBath, ρ0::Matrix{ComplexF64}, classical_dt::Float64, dt::Float64, ntimes::Int64, kmax::Int64, path_integral_routine::typeof(QuantumDynamics.QuAPI.propagate), extraargs::QuantumDynamics.QuAPI.QuAPIArgs, svec::Matrix{Float64}, verbose::Bool)
#     @ QuantumDynamics.QCPI ~/.julia/packages/QuantumDynamics/bk7Hq/src/QCPI.jl:15
#  [10] top-level scope
#     @ In[17]:6

# %% [markdown]
# HEOM only runs with Drude-Lorentz spectral densities...

# %%
## Running with HEOM

λs = repeat([35.0], N) * invcm2au
γs = 1 ./ (repeat([50.0], N) ./ au2fs)
JwD = Vector{SpectralDensities.DrudeLorentz}()
sys_ops = Vector{Matrix{ComplexF64}}()
for (j, (λ, γ)) in enumerate(zip(λs, γs))
    push!(JwD, SpectralDensities.DrudeLorentz(; λ, γ, Δs=1.0))
    op = zeros(N, N)
    op[j, j] = 1.0
    push!(sys_ops, op)
end

@time th, ρh = HEOM.propagate(; Hamiltonian=H0, ρ0=ρ0, Jw=JwD, β, ntimes=nsteps, dt, sys_ops, num_modes=2, Lmax=3, scaled=true, threshold=1e-10, extraargs=Utilities.DiffEqArgs(; reltol=1e-6, abstol=1e-6))
th .*= au2fs
# Out:
# 148.802611 seconds (189.24 M allocations: 102.446 GiB, 11.85% gc time, 0.01% compilation time)
# 1001-element Vector{Float64}:
#  0.0
#  0.001
#  0.002
#  0.003
#  0.004
#  0.005
#  0.006
#  0.007
#  0.008
#  0.009000000000000001
#  0.01
#  0.011000000000000001
#  0.012
#  ⋮
#  0.9890000000000001
#  0.9900000000000001
#  0.9910000000000001
#  0.9920000000000001
#  0.9930000000000001
#  0.9940000000000001
#  0.9950000000000001
#  0.9960000000000001
#  0.9970000000000001
#  0.9980000000000001
#  0.9990000000000001
#  1.0

# %%
MSD = []
for i in 1:nsteps
    s = 0.0
    for j in 1:N
        s += real(ρh[i, j, j])*((j-5)^2)
    end
    push!(MSD, s)
end

# %%
display("text/plain", MSD)
# Out:
# 1000-element Vector{Any}:
#  0.0
#  1.3067042973430503e-9
#  5.226816718759916e-9
#  1.1760336554816846e-8
#  2.09072630914146e-8
#  3.2667595609634856e-8
#  4.704133338584267e-8
#  6.40284756917002e-8
#  8.36290217941657e-8
#  1.0584297095549294e-7
#  1.3067032243323329e-7
#  1.58111075480235e-7
#  1.8816522934463934e-7
#  ⋮
#  0.0012752375460405399
#  0.0012778198281978052
#  0.0012804047208805132
#  0.001282992224083635
#  0.0012855823378021404
#  0.0012881750620309914
#  0.0012907703967651493
#  0.0012933683419995682
#  0.0012959688977292015
#  0.0012985720639489948
#  0.0013011778406538932
#  0.0013037862278388356

# %%
μ = β * (MSD[nsteps] - MSD[1])/(th[nsteps] - th[1])
# Out:
# 1.3737094814667385

# %%
t .*= au2fs
# Out:
# UndefVarError: `t` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[39]:1

# %%
plot(th[1:nsteps], MSD, fmt= :png)

# %%
plot(th, real.(ρh[:, 5, 5]), label="site 5")
plot!(th, real.(ρh[:, 4, 4]), label="site 4")
plot!(th, real.(ρh[:, 3, 3]), label="site 3")
plot!(th, real.(ρh[:, 2, 2]), label="site 2")
plot!(th, real.(ρh[:, 1, 1]), label="site 1")
