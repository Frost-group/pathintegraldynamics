# %%
using QuantumDynamics
using Plots
using LinearAlgebra

# %% [markdown]
# Hoping to get rid of the units issue by integrating Unitful into QuantumDynamics package.

# %%
const thz2au = 0.0001519828500716
const invcm2au = 4.55633e-6
const au2fs = 0.02418884254
const mev2invcm = 8.066
# Out:
# 8.066

# %%
struct fitsd <: SpectralDensities.AnalyticalSpectralDensity
    ωs :: Vector{Float64}
    jws :: Vector{Float64}
    ωmax :: Real
    Δs :: Real
    classical :: Bool
end

# %% [markdown]
# Gaussian broadening distribution

# %%
σ = 5*invcm2au
function evaluate(sd::fitsd, ω::Real)
    ωs = sd.ωs
    jws = sd.jws
    
    s = 0.0
    for i in 1:(size(ωs)[1])
        for j in 1:(size(ωs)[1]) 
            s += jws[j]*exp(-((((ω-ωs[i])/σ)^2)))
        end
    end
    s
end
# Out:
# evaluate (generic function with 1 method)

# %%
#=function tabulate(sd::fitsd, full_real::Bool=true, npoints::Int=5)
    sd.ωs, sd.jws
end=#
# Out:
# tabulate (generic function with 3 methods)

# %%
(sd::fitsd)(ω::Real) = evaluate(sd, ω)

# %% [markdown]
# Ordejon paper mentions that Hamiltonian electronic terms are $\epsilon_0$ , $\epsilon_{AA+b}$ and $\epsilon_{AA+2b}$ for nearest 2 neighbours and additionally mentions that the coupling terms for nearest 2 neighbours on either side. Further mentions the couplings $\epsilon$AB, AC, AD for neighbours on the same unit cell. However, the value for $\epsilon_0$ (site energies) isn't mentioned in the paper? Perhaps worth doing some TD-DFT ourselves? Or alternatively some TrESP-ish method for 1-D... have to think about this for a bit

# %%
ϵ0 = 0.0 # Based on typical NN exciton Hamiltonians
ϵb = 134.0
ϵ2b = -10.7
# Out:
# -10.7

# %%
N = 10
# Out:
# 10

# %%
H0 = Matrix{ComplexF64}(zeros(N, N))
# Out:
# 10×10 Matrix{ComplexF64}:
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  …  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  …  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im     0.0+0.0im  0.0+0.0im  0.0+0.0im

# %%
for i in 1:N
    H0[i,i] = ϵ0
    if i <= N-2
        H0[i, i+2] = ϵ2b
    end
    if i <= N-1
        H0[i, i+1] = ϵb
    end
    if i >= 2
        H0[i, i-1] = ϵb
    end
    if i>=3
        H0[i, i-2] = ϵ2b
    end
end

# %%
H0 = H0 * invcm2au
# Out:
# 10×10 Matrix{ComplexF64}:
#          0.0+0.0im  0.000610548+0.0im  …          0.0+0.0im
#  0.000610548+0.0im          0.0+0.0im             0.0+0.0im
#  -4.87527e-5+0.0im  0.000610548+0.0im             0.0+0.0im
#          0.0+0.0im  -4.87527e-5+0.0im             0.0+0.0im
#          0.0+0.0im          0.0+0.0im             0.0+0.0im
#          0.0+0.0im          0.0+0.0im  …          0.0+0.0im
#          0.0+0.0im          0.0+0.0im             0.0+0.0im
#          0.0+0.0im          0.0+0.0im     -4.87527e-5+0.0im
#          0.0+0.0im          0.0+0.0im     0.000610548+0.0im
#          0.0+0.0im          0.0+0.0im             0.0+0.0im

# %%
ωp = [57.8, 59.6, 89.0, 107.3, 139.1, 639.1, 1011.2, 1344.7, 1593.3] .* invcm2au
ωpg0p = [-1.7, 1.4, 1.6, -0.14, -2.3, -7.5, -3.6, 19.8, -42.0] * invcm2au
g0p = ωpg0p ./ ωp
jws = ((g0p.^(2))./ωp)
#Jw = SpectralDensities.ExponentialCutoff(; ξ=30.0, ωc=57.8*invcm2au, n=0.0, Δs=1.0)
wm = maximum(ωp)
Jw = fitsd(ωp, jws, wm, 1.0, false)
# Out:
# fitsd([0.000263355874, 0.00027155726800000003, 0.00040551337, 0.0004888942090000001, 0.000633785503, 0.002911950503, 0.004607360896, 0.006126896951000001, 0.007259600589], [3.284726062780688, 2.0318990209622005, 0.7969934905542059, 0.0034821039706774974, 0.4313791108898418, 0.04729343983355628, 0.002750924350825124, 0.035386612864194956, 0.095717366517124], 0.007259600589, 1.0, false)

# %%
ω = 0:0.0001:0.07
plot(ω, Jw.(ω))

# %%
nsteps = 1000
ρ0 = Matrix{ComplexF64}(zeros(N, N))
ρ0[5, 5] = 1

T = 50.0:50.0:500.0

β = 1 / (T[6] * 3.16683e-6) # T = 300K
# Out:
# 1052.5772881188234

# %% [markdown]
# Simulation is very sensitive to time-stepping. NaNs get produced if you're not careful

# %%
dt = 0.25
# Out:
# 0.25

# %%
fbU = Propagators.calculate_bare_propagators(; Hamiltonian=H0, dt=dt, ntimes=nsteps)    
t, ρ = TTM.propagate(; fbU=fbU, Jw=[Jw], β=β, ρ0=ρ0, dt=dt, ntimes=nsteps, rmax=1, extraargs=QuAPI.QuAPIArgs(), path_integral_routine=QuAPI.build_augmented_propagator)

# %% [markdown]
# QCPI doesn't compile. I need to figure out where the pipeline is going wrong

# %%
## QCPI Run

ω, c = discretize(Jw, 9)
hb = Solvents.HarmonicBath(β, ω, c, [1.0, -1.0], 10)

tc, ρc = QCPI.propagate(; Hamiltonian=H0, Jw, solvent=hb, ρ0, classical_dt=dt / 100, dt, ntimes=nsteps, kmax=1, extraargs=QuAPI.QuAPIArgs(), path_integral_routine=QuAPI.propagate, verbose=false)
# Out:
# DimensionMismatch: array could not be broadcast to match destination
#
# Stacktrace:
#   [1] check_broadcast_shape
#     @ ./broadcast.jl:553 [inlined]
#   [2] check_broadcast_axes
#     @ ./broadcast.jl:556 [inlined]
#   [3] check_broadcast_axes
#     @ ./broadcast.jl:560 [inlined]
#   [4] instantiate
#     @ ./broadcast.jl:297 [inlined]
#   [5] materialize!
#     @ ./broadcast.jl:884 [inlined]
#   [6] materialize!
#     @ ./broadcast.jl:881 [inlined]
#   [7] calculate_reference_propagators(; Hamiltonian::Matrix{ComplexF64}, solvent::QuantumDynamics.Solvents.HarmonicBath, ps::QuantumDynamics.Solvents.HarmonicPhaseSpace, classical_dt::Float64, dt::Float64, ref_pos::Nothing, ntimes::Int64)
#     @ QuantumDynamics.Propagators ~/.julia/packages/QuantumDynamics/bk7Hq/src/Propagators.jl:48
#   [8] calculate_reference_propagators
#     @ ~/.julia/packages/QuantumDynamics/bk7Hq/src/Propagators.jl:25 [inlined]
#   [9] propagate(; Hamiltonian::Matrix{ComplexF64}, Jw::fitsd, solvent::QuantumDynamics.Solvents.HarmonicBath, ρ0::Matrix{ComplexF64}, classical_dt::Float64, dt::Float64, ntimes::Int64, kmax::Int64, path_integral_routine::typeof(QuantumDynamics.QuAPI.propagate), extraargs::QuantumDynamics.QuAPI.QuAPIArgs, svec::Matrix{Float64}, verbose::Bool)
#     @ QuantumDynamics.QCPI ~/.julia/packages/QuantumDynamics/bk7Hq/src/QCPI.jl:15
#  [10] top-level scope
#     @ In[17]:6

# %% [markdown]
# HEOM only runs with Drude-Lorentz spectral densities...

# %%
## Running with HEOM

λs = repeat([35.0], N) * invcm2au
γs = 1 ./ (repeat([50.0], N) ./ au2fs)
JwD = Vector{SpectralDensities.DrudeLorentz}()
sys_ops = Vector{Matrix{ComplexF64}}()
for (j, (λ, γ)) in enumerate(zip(λs, γs))
    push!(JwD, SpectralDensities.DrudeLorentz(; λ, γ, Δs=1.0))
    op = zeros(N, N)
    op[j, j] = 1.0
    push!(sys_ops, op)
end

@time th, ρh = HEOM.propagate(; Hamiltonian=H0, ρ0=ρ0, Jw=JwD, β, ntimes=nsteps, dt, sys_ops, num_modes=2, Lmax=3, scaled=true, threshold=1e-10, extraargs=Utilities.DiffEqArgs(; reltol=1e-6, abstol=1e-6))
# Out:
# 172.866153 seconds (204.49 M allocations: 103.351 GiB, 12.03% gc time, 7.05% compilation time)
# ([0.0, 0.04134137457575099, 0.08268274915150198, 0.12402412372725297, 0.16536549830300395, 0.20670687287875494, 0.24804824745450593, 0.2893896220302569, 0.3307309966060079, 0.3720723711817589  …  40.96930220456923, 41.01064357914498, 41.05198495372073, 41.093326328296484, 41.134667702872235, 41.176009077447986, 41.21735045202374, 41.25869182659949, 41.30003320117524, 41.34137457575099], [0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; 4.1254712380377936e-24 + 0.0im -1.0332992641140066e-22 + 5.940523320997629e-26im … 4.125470501992541e-24 + 2.5090868401503146e-35im 1.086531262103404e-30 - 2.281390589777094e-28im; … ; 4.445525099424744e-12 + 0.0im -1.0367303837358203e-10 + 2.7002049567841067e-11im … 4.443639865476778e-12 + 1.5084311064973053e-16im -2.1779624369062965e-14 - 1.0590624308875383e-13im; 4.464029226294137e-12 + 0.0im -1.0409030999790148e-10 + 2.713751638336541e-11im … 4.4621329118159375e-12 + 1.5190353180259193e-16im -2.191080226831292e-14 - 1.0644201071691874e-13im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; -1.0332992641140066e-22 - 5.940523320997629e-26im 2.5880776732297278e-21 + 0.0im … -1.0332992342920573e-22 - 5.940528334452992e-26im 6.754598246942889e-30 + 5.714128859021449e-27im; … ; -1.0367303837358203e-10 - 2.7002049567841067e-11im 2.582640122722032e-9 + 0.0im … -1.0364959906211881e-10 - 2.6997787018541514e-11im -1.3534856318348297e-13 + 2.6026328089079684e-12im; -1.0409030999790148e-10 - 2.713751638336541e-11im 2.5930067923929875e-9 + 0.0im … -1.0406673118070718e-10 - 2.713322498577951e-11im -1.3616369287882295e-13 + 2.615700814264577e-12im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; -6.470189639190251e-22 + 4.093752273487433e-18im -1.0700488198332927e-20 - 1.025350939484491e-16im … -6.470190166321214e-22 + 4.093752087335681e-18im 1.0332989025748772e-22 - 1.1812491308482854e-26im; … ; -6.487582425920509e-10 + 4.244898119461312e-9im -1.0650940257081211e-8 - 1.0294731101727057e-7im … -6.487984036386307e-10 + 4.243449995648871e-9im 1.043133204379217e-10 - 5.338320748575612e-12im; -6.513686951151447e-10 + 4.257987121813283e-9im -1.0693637120470927e-8 - 1.0325823557932993e-7im … -6.514090740520166e-10 + 4.256531889234877e-9im 1.0473444776363872e-10 - 5.3650381848856485e-12im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; 1.61023886354796e-20 - 5.1267544018395653e-17im -6.635595431383707e-20 + 1.2840843314423353e-15im … 1.6102388097296163e-20 - 5.126754400051116e-17im -1.2940389186564232e-21 - 2.944402811314614e-25im; … ; 1.6022613264899916e-8 - 5.065283195293529e-8im -6.600572972285858e-8 + 1.2789557682660435e-6im … 1.602049205040051e-8 - 5.06446628582635e-8im -1.2855310013130565e-9 - 1.335601935485934e-10im; 1.60868372817404e-8 - 5.080418066066888e-8im -6.627028096193202e-8 + 1.2827979948305714e-6im … 1.608470362683926e-8 - 5.079597060460897e-8im -1.2906795907884423e-9 - 1.342297378601361e-10im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; -2.031129645024809e-12 - 6.420420392195447e-16im 5.087315415753341e-11 + 2.731440706768873e-15im … -2.031129644701316e-12 - 6.420420391592342e-16im -5.427732513241623e-21 + 5.1267544680933125e-17im; … ; -2.0069259700289602e-6 - 6.391138991324383e-7im 5.0695532274566506e-5 + 2.7167640056434674e-6im … -2.006604586811093e-6 - 6.390865631772546e-7im -5.395596545432001e-9 + 5.095342951896905e-8im; -2.0109058934016353e-6 - 6.410333160257907e-7im 5.079693320568834e-5 + 2.7249209694144084e-6im … -2.010583223031774e-6 - 6.410058430690735e-7im -5.417216248401855e-9 + 5.11062852553737e-8im;;; 0.0 + 0.0im 0.0 + 0.0im … 0.0 + 0.0im 0.0 + 0.0im; 1.6102388063621745e-20 - 5.1267544018400886e-17im -6.635596309898542e-20 + 1.284084302471351e-15im … 1.6102388669152864e-20 - 5.126754400050581e-17im -1.2940389416399965e-21 - 2.9444040420210224e-25im; … ; 1.6021165554299636e-8 - 5.0652771084117724e-8im -6.600227901900094e-8 + 1.2788342989116326e-6im … 1.6021939742969014e-8 - 5.0644723441233024e-8im -1.2855896751402832e-9 - 1.335665412350139e-10im; 1.6085381184 ...

# %%
MSD = []
for i in 1:nsteps
    s = 0.0
    for j in 1:N
        s += real(ρh[i, j, j])*((j-5)^2)
    end
    push!(MSD, s)
end

# %%
display("text/plain", MSD)
# Out:
# 1000-element Vector{Any}:
#  0.0
#  1.3067042973430503e-9
#  5.226816718759916e-9
#  1.1760336554816846e-8
#  2.09072630914146e-8
#  3.2667595609634856e-8
#  4.704133338584267e-8
#  6.40284756917002e-8
#  8.36290217941657e-8
#  1.0584297095549294e-7
#  1.3067032243323329e-7
#  1.58111075480235e-7
#  1.8816522934463934e-7
#  ⋮
#  0.0012752375460405399
#  0.0012778198281978052
#  0.0012804047208805132
#  0.001282992224083635
#  0.0012855823378021404
#  0.0012881750620309914
#  0.0012907703967651493
#  0.0012933683419995682
#  0.0012959688977292015
#  0.0012985720639489948
#  0.0013011778406538932
#  0.0013037862278388356

# %%
μ = β * (MSD[nsteps] - MSD[1])/(th[nsteps] - th[1])
# Out:
# 1.3737094814667385

# %%
t .*= au2fs
# Out:
# UndefVarError: `t` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[39]:1

# %%
plot(th[1:nsteps], MSD, fmt= :png)

# %%
plot(th, real.(ρh[:, 5, 5]), label="site 5")
plot!(th, real.(ρh[:, 4, 4]), label="site 4")
plot!(th, real.(ρh[:, 3, 3]), label="site 3")
plot!(th, real.(ρh[:, 2, 2]), label="site 2")
plot!(th, real.(ρh[:, 1, 1]), label="site 1")
