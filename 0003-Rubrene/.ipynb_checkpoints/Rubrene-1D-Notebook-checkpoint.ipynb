# %%
using QuantumDynamics
using Plots
using LinearAlgebra

# %% [markdown]
# Hoping to get rid of the units issue by integrating Unitful into QuantumDynamics package.

# %%
const thz2au = 0.0001519828500716
const invcm2au = 4.55633e-6
const au2fs = 0.02418884254
const mev2invcm = 8.066
# Out:
# 8.066

# %%
struct fitsd <: SpectralDensities.AnalyticalSpectralDensity
    ωs :: Vector{Float64}
    jws :: Vector{Float64}
    ωmax :: Real
    Δs :: Real
    classical :: Bool
end

# %% [markdown]
# No good way to add spectral densities from discrete measured phonon modes yet. So far just drew a straight line between the two points. Would like to do a Gaussian blur at each point.

# %%
function evaluate(sd::fitsd, ω::Real)
    ωs = sd.ωs
    jws = sd.jws
    for i in 1:(size(ωs)[1]-1)
        if ω > ωs[i] && ω < ωs[i+1]
            return jws[i] + ((jws[i+1]-jws[i])/(ωs[i+1] - ωs[i]))*(ω - ωs[i])
        end
    end
    return 0.0
end
# Out:
# evaluate (generic function with 1 method)

# %%
function tabulate(sd::fitsd, full_real::Bool=true, npoints::Int=5)
    sd.ωs, sd.jws
end
# Out:
# tabulate (generic function with 3 methods)

# %%
(sd::fitsd)(ω::Real) = evaluate(sd, ω)

# %% [markdown]
# Ordejon paper mentions that Hamiltonian electronic terms are $\epsilon_0$ , $\epsilon_{AA+b}$ and $\epsilon_{AA+2b}$ for nearest 2 neighbours and additionally mentions that the coupling terms for nearest 2 neighbours on either side. Further mentions the couplings $\epsilon$AB, AC, AD for neighbours on the same unit cell. However, the value for $\epsilon_0$ (site energies) isn't mentioned in the paper? Perhaps worth doing some TD-DFT ourselves? Or alternatively some TrESP-ish method for 1-D... have to think about this for a bit

# %%
ϵ0 = 12000 # Completely arbitrary value 
ϵb = 134.0
ϵ2b = -10.7
# Out:
# -10.7

# %%
N = 5
# Out:
# 5

# %%
H0 = Matrix{ComplexF64}(zeros(N, N))
# Out:
# 5×5 Matrix{ComplexF64}:
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im
#  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im  0.0+0.0im

# %%
for i in 1:N
    H0[i,i] = ϵ0
    if i <= N-2
        H0[i, i+2] = ϵ2b
    end
    if i <= N-1
        H0[i, i+1] = ϵb
    end
    if i >= 2
        H0[i, i-1] = ϵb
    end
    if i>=3
        H0[i, i-2] = ϵ2b
    end
end

# %%
H0 = H0 * invcm2au
# Out:
# 5×5 Matrix{ComplexF64}:
#     0.054676+0.0im  0.000610548+0.0im  …          0.0+0.0im
#  0.000610548+0.0im     0.054676+0.0im             0.0+0.0im
#  -4.87527e-5+0.0im  0.000610548+0.0im     -4.87527e-5+0.0im
#          0.0+0.0im  -4.87527e-5+0.0im     0.000610548+0.0im
#          0.0+0.0im          0.0+0.0im        0.054676+0.0im

# %%
ωp = [57.8, 59.6, 89.0, 107.3, 139.1, 639.1, 1011.2, 1344.7, 1593.3] .* invcm2au
ωpg0p = [-1.7, 1.4, 1.6, -0.14, -2.3, -7.5, -3.6, 19.8, -42.0] * invcm2au
g0p = ωpg0p ./ ωp
jws = ((g0p.^(2))./ωp)
#Jw = SpectralDensities.ExponentialCutoff(; ξ=30.0, ωc=57.8*invcm2au, n=0.0, Δs=1.0)
wm = maximum(ωp)
Jw = fitsd(ωp, jws, wm, 1.0, false)
# Out:
# 9-element Vector{Float64}:
#  3.284726062780688
#  2.0318990209622005
#  0.7969934905542059
#  0.0034821039706774974
#  0.4313791108898418
#  0.04729343983355628
#  0.002750924350825124
#  0.035386612864194956
#  0.095717366517124

# %%
# %%
## QCPI Run
#=
ωs, c = SpectralDensities.discretize(Jw, 100)
hb = Solvents.HarmonicBath(β, ωs, c, [1.0, -1.0], 10)

tc, ρc = QCPI.propagate(; Hamiltonian=H0, Jw, solvent=hb, ρ0, classical_dt=dt / 100, dt, ntimes=nsteps, kmax=1, extraargs=QuAPI.QuAPIArgs(), path_integral_routine=QuAPI.propagate)
=#
# Out:
# DimensionMismatch: array could not be broadcast to match destination
#
# Stacktrace:
#   [1] check_broadcast_shape
#     @ ./broadcast.jl:553 [inlined]
#   [2] check_broadcast_axes
#     @ ./broadcast.jl:556 [inlined]
#   [3] check_broadcast_axes
#     @ ./broadcast.jl:560 [inlined]
#   [4] instantiate
#     @ ./broadcast.jl:297 [inlined]
#   [5] materialize!
#     @ ./broadcast.jl:884 [inlined]
#   [6] materialize!
#     @ ./broadcast.jl:881 [inlined]
#   [7] calculate_reference_propagators(; Hamiltonian::Matrix{ComplexF64}, solvent::QuantumDynamics.Solvents.HarmonicBath, ps::QuantumDynamics.Solvents.HarmonicPhaseSpace, classical_dt::Float64, dt::Float64, ref_pos::Nothing, ntimes::Int64)
#     @ QuantumDynamics.Propagators ~/.julia/packages/QuantumDynamics/bk7Hq/src/Propagators.jl:48
#   [8] calculate_reference_propagators
#     @ ~/.julia/packages/QuantumDynamics/bk7Hq/src/Propagators.jl:25 [inlined]
#   [9] propagate(; Hamiltonian::Matrix{ComplexF64}, Jw::QuantumDynamics.SpectralDensities.ExponentialCutoff, solvent::QuantumDynamics.Solvents.HarmonicBath, ρ0::Matrix{ComplexF64}, classical_dt::Float64, dt::Float64, ntimes::Int64, kmax::Int64, path_integral_routine::typeof(QuantumDynamics.QuAPI.propagate), extraargs::QuantumDynamics.QuAPI.QuAPIArgs, svec::Matrix{Float64}, verbose::Bool)
#     @ QuantumDynamics.QCPI ~/.julia/packages/QuantumDynamics/bk7Hq/src/QCPI.jl:15
#  [10] top-level scope
#     @ In[56]:6

# %%
MSD = []
for i in 1:nsteps
    s = 0.0
    for j in 1:N
        s += real(ρ[i, j, j])*((j-5)^2)
    end
    push!(MSD, s)
end

# %%
display("text/plain", MSD)
# Out:
# 2000-element Vector{Any}:
#  0.0
#  2.3892277945119887e-8
#  9.55691140731669e-8
#  2.1503266421827509e-7
#  3.8228514747214934e-7
#  5.973290277354112e-7
#  8.601497969266916e-7
#  1.1707136642712704e-6
#  1.5289868652610653e-6
#  1.9349356619631654e-6
#  2.3885263433243967e-6
#  2.88972522547477e-6
#  3.4384986520381613e-6
#  ⋮
#  0.08552153822688123
#  0.08561139688526119
#  0.08570130675421207
#  0.0857912678385883
#  0.08588128014323772
#  0.08597134367300135
#  0.0860614584327137
#  0.08615162442720248
#  0.08624184166128855
#  0.08633211013978598
#  0.08642242986750204
#  0.086512800849237

# %%
μ = β * (MSD[20] - MSD[1])/(t[20] - t[1])
# Out:
# 0.0019077528281459836

# %%
plot(t[1:nsteps], MSD, fmt= :png)

# %%
plot(t, real.(ρ[:, 5, 5]), label="site 5")
plot!(t, real.(ρ[:, 4, 4]), label="site 4")
plot!(t, real.(ρ[:, 3, 3]), label="site 3")
plot!(t, real.(ρ[:, 2, 2]), label="site 2")
plot!(t, real.(ρ[:, 1, 1]), label="site 1")
